# %%
## Imports ##
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree, preprocessing
from sklearn.model_selection import KFold, train_test_split, KFold, GridSearchCV
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import pydot

# %%
## Step 1 ##
df = pd.read_csv("Titanic.csv")

le = preprocessing.LabelEncoder()
df = df.apply(le.fit_transform)

enc = preprocessing.OneHotEncoder()
enc.fit(df)
onehotlabels = enc.transform(df).toarray()
print(onehotlabels.shape)

X = pd.concat([df['pclass'],df['sex'],df['age'],df['sibsp']], axis=1)
X = df.loc[:, df.columns != target]
y = df['survived']
df.describe()
# Out:
# (1309, 4658)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-227-505fc8ed95ce> in <module>
#      11
#      12 X = pd.concat([df['pclass'],df['sex'],df['age'],df['sibsp']], axis=1)
# ---> 13 X = df.loc[:, df.columns != target]
#      14 y = df['survived']
#      15 df.describe()
#
# NameError: name 'target' is not defined

# %%
X.head()
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pclass  1309 non-null   int32
#  1   sex     1309 non-null   int32
#  2   age     1309 non-null   int64
#  3   sibsp   1309 non-null   int64
# dtypes: int32(2), int64(2)
# memory usage: 30.8 KB

# %%
## Step 2 ##
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True)
print(X_train)
clf = DecisionTreeClassifier(max_leaf_nodes=10)
clf = clf.fit(X_train, y_train)

print(tree.plot_tree(clf, filled=True, feature_names=X_train.columns))
# Out:
#      pclass  sex  age  sibsp
# 892       2    1   47      0
# 839       2    1   28      0
# 252       0    1   85      1
# 447       1    1   34      2
# 837       2    1   56      2
# ..      ...  ...  ...    ...
# 713       2    1   31      0
# 283       0    1   98      0
# 468       1    0   32      0
# 962       2    1   98      1
# 448       1    1   54      0
#
# [1047 rows x 4 columns]
# [Text(141.64615384615385, 199.32, 'sex <= 0.5\ngini = 0.471\nsamples = 1047\nvalue = [650, 397]'), Text(51.50769230769231, 163.07999999999998, 'pclass <= 1.5\ngini = 0.396\nsamples = 371\nvalue = [101, 270]'), Text(25.753846153846155, 126.83999999999999, 'gini = 0.119\nsamples = 205\nvalue = [13, 192]'), Text(77.26153846153846, 126.83999999999999, 'sibsp <= 2.5\ngini = 0.498\nsamples = 166\nvalue = [88, 78]'), Text(51.50769230769231, 90.6, 'age <= 25.0\ngini = 0.5\nsamples = 151\nvalue = [75, 76]'), Text(25.753846153846155, 54.359999999999985, 'gini = 0.397\nsamples = 22\nvalue = [6, 16]'), Text(77.26153846153846, 54.359999999999985, 'age <= 84.0\ngini = 0.498\nsamples = 129\nvalue = [69, 60]'), Text(51.50769230769231, 18.119999999999976, 'gini = 0.484\nsamples = 85\nvalue = [50, 35]'), Text(103.01538461538462, 18.119999999999976, 'gini = 0.491\nsamples = 44\nvalue = [19, 25]'), Text(103.01538461538462, 90.6, 'gini = 0.231\nsamples = 15\nvalue = [13, 2]'), Text(231.7846153846154, 163.07999999999998, 'age <= 19.5\ngini = 0.305\nsamples = 676\nvalue = [549, 127]'), Text(180.27692307692308, 126.83999999999999, 'sibsp <= 2.5\ngini = 0.485\nsamples = 41\nvalue = [17, 24]'), Text(154.52307692307693, 90.6, 'age <= 4.5\ngini = 0.204\nsamples = 26\nvalue = [3, 23]'), Text(128.76923076923077, 54.359999999999985, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'), Text(180.27692307692308, 54.359999999999985, 'gini = 0.083\nsamples = 23\nvalue = [1, 22]'), Text(206.03076923076924, 90.6, 'gini = 0.124\nsamples = 15\nvalue = [14, 1]'), Text(283.2923076923077, 126.83999999999999, 'pclass <= 0.5\ngini = 0.272\nsamples = 635\nvalue = [532, 103]'), Text(257.53846153846155, 90.6, 'gini = 0.426\nsamples = 133\nvalue = [92, 41]'), Text(309.04615384615386, 90.6, 'gini = 0.217\nsamples = 502\nvalue = [440, 62]')]

# %%
## Step 3 ##
print("Training Dataset: ")
y_pred = clf.predict(X_train)
print(classification_report(y_train, y_pred))

print("\nTest Dataset: ")
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# Training Dataset:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87       650
#            1       0.87      0.64      0.74       397
#
#     accuracy                           0.83      1047
#    macro avg       0.84      0.79      0.80      1047
# weighted avg       0.83      0.83      0.82      1047
#
#
# Test Dataset:
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.83       159
#            1       0.80      0.58      0.67       103
#
#     accuracy                           0.78       262
#    macro avg       0.79      0.74      0.75       262
# weighted avg       0.78      0.78      0.77       262

# %%
## Step 4 ##
tree_sizes = [size for size in range(2,10)]
tree_para = {'criterion':['gini'],'max_leaf_nodes':tree_sizes}
clf = GridSearchCV(DecisionTreeClassifier(), tree_para, cv=5)
clf.fit(X_train, y_train)

scores = clf.cv_results_['mean_test_score']
scores = np.ones(len(tree_sizes))-scores
scores *= len(X_test)

plt.plot(tree_sizes,scores)
plt.title('Misclassifications vs Size')
plt.xlabel('Size')
plt.ylabel('Misclassifications')
plt.show()

# %%
## Step 5 ##
clf_best = DecisionTreeClassifier()
clf_best.set_params(**clf.best_params_)
clf_best.fit(X_train, y_train)
print(tree.plot_tree(clf_best, filled=True, feature_names=X_train.columns))
# Out:
# [Text(167.4, 190.26, 'sex <= 0.5\ngini = 0.471\nsamples = 1047\nvalue = [650, 397]'), Text(83.7, 135.9, 'pclass <= 1.5\ngini = 0.396\nsamples = 371\nvalue = [101, 270]'), Text(41.85, 81.53999999999999, 'gini = 0.119\nsamples = 205\nvalue = [13, 192]'), Text(125.55000000000001, 81.53999999999999, 'gini = 0.498\nsamples = 166\nvalue = [88, 78]'), Text(251.10000000000002, 135.9, 'age <= 19.5\ngini = 0.305\nsamples = 676\nvalue = [549, 127]'), Text(209.25, 81.53999999999999, 'sibsp <= 2.5\ngini = 0.485\nsamples = 41\nvalue = [17, 24]'), Text(167.4, 27.180000000000007, 'gini = 0.204\nsamples = 26\nvalue = [3, 23]'), Text(251.10000000000002, 27.180000000000007, 'gini = 0.124\nsamples = 15\nvalue = [14, 1]'), Text(292.95, 81.53999999999999, 'gini = 0.272\nsamples = 635\nvalue = [532, 103]')]

# %%
## Step 6 ##
y_pred = clf_best.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82       159
#            1       0.88      0.43      0.58       103
#
#     accuracy                           0.75       262
#    macro avg       0.80      0.69      0.70       262
# weighted avg       0.78      0.75      0.73       262
